# %%
# !pip install wandb
# Out:
# Requirement already satisfied: wandb in /media/aria/SSD/anaconda/lib/python3.13/site-packages (0.23.0)
# Requirement already satisfied: click>=8.0.1 in /media/aria/SSD/anaconda/lib/python3.13/site-packages (from wandb) (8.1.8)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /media/aria/SSD/anaconda/lib/python3.13/site-packages (from wandb) (3.1.43)
# Requirement already satisfied: packaging in /media/aria/SSD/anaconda/lib/python3.13/site-packages (from wandb) (24.2)
# Requirement already satisfied: platformdirs in /media/aria/SSD/anaconda/lib/python3.13/site-packages (from wandb) (4.3.7)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /media/aria/SSD/anaconda/lib/python3.13/site-packages (from wandb) (5.29.3)
# Requirement already satisfied: pydantic<3 in /media/aria/SSD/anaconda/lib/python3.13/site-packages (from wandb) (2.10.3)
# Requirement already satisfied: pyyaml in /media/aria/SSD/anaconda/lib/python3.13/site-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /media/aria/SSD/anaconda/lib/python3.13/site-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /media/aria/SSD/anaconda/lib/python3.13/site-packages (from wandb) (2.18.0)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /media/aria/SSD/anaconda/lib/python3.13/site-packages (from wandb) (4.12.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /media/aria/SSD/anaconda/lib/python3.13/site-packages (from pydantic<3->wandb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /media/aria/SSD/anaconda/lib/python3.13/site-packages (from pydantic<3->wandb) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /media/aria/SSD/anaconda/lib/python3.13/site-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /media/aria/SSD/anaconda/lib/python3.13/site-packages (from requests<3,>=2.0.0->wandb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /media/aria/SSD/anaconda/lib/python3.13/site-packages (from requests<3,>=2.0.0->wandb) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /media/aria/SSD/anaconda/lib/python3.13/site-packages (from requests<3,>=2.0.0->wandb) (2025.10.5)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /media/aria/SSD/anaconda/lib/python3.13/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in /media/aria/SSD/anaconda/lib/python3.13/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (4.0.0)

# %%
import wandb

# %%
wandb.login(key='49267da1ae2dec1fd8edb03ae6548ad0227623c4')
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /home/aria/.netrc
# True

# %%
import random

# Launch 5 simulated experiments
for run in range(5):
    # 1️⃣ Start a new run to track this script
    wandb.init(
        project="basic-intro",
        config={
            "learning_rate": 0.02,
            "architecture": "CNN",
            "dataset": "CIFAR-100",
        },
    )

    # This simple block simulates a training loop logging metrics
    offset = random.random() / 5
    for ii in range(2, 10):
        acc = 1 - 2**-ii - random.random() / ii - offset
        loss = 2**-ii + random.random() / ii + offset
        # 2️⃣ Log metrics from your script to W&B
        wandb.log({"acc": acc, "loss": loss})

    wandb.finish()
# Out:
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/home/aria/machine learning-my code/wandb/wandb/run-20251112_162040-96po8huf</code>
# Syncing run <strong><a href='https://wandb.ai/a-j-ch1386-self-emploid/basic-intro/runs/96po8huf' target="_blank">ruby-valley-11</a></strong> to <a href='https://wandb.ai/a-j-ch1386-self-emploid/basic-intro' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/a-j-ch1386-self-emploid/basic-intro' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/basic-intro</a>
#  View run at <a href='https://wandb.ai/a-j-ch1386-self-emploid/basic-intro/runs/96po8huf' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/basic-intro/runs/96po8huf</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>acc</td><td>▁▅▇█████</td></tr><tr><td>loss</td><td>█▆▂▃▁▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>acc</td><td>0.88102</td></tr><tr><td>loss</td><td>0.17126</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ruby-valley-11</strong> at: <a href='https://wandb.ai/a-j-ch1386-self-emploid/basic-intro/runs/96po8huf' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/basic-intro/runs/96po8huf</a><br> View project at: <a href='https://wandb.ai/a-j-ch1386-self-emploid/basic-intro' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/basic-intro</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251112_162040-96po8huf/logs</code>
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/home/aria/machine learning-my code/wandb/wandb/run-20251112_162044-vkup63i9</code>
# Syncing run <strong><a href='https://wandb.ai/a-j-ch1386-self-emploid/basic-intro/runs/vkup63i9' target="_blank">morning-capybara-12</a></strong> to <a href='https://wandb.ai/a-j-ch1386-self-emploid/basic-intro' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/a-j-ch1386-self-emploid/basic-intro' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/basic-intro</a>
#  View run at <a href='https://wandb.ai/a-j-ch1386-self-emploid/basic-intro/runs/vkup63i9' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/basic-intro/runs/vkup63i9</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>acc</td><td>▁▅▅▅▇█▇█</td></tr><tr><td>loss</td><td>█▅▄▂▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>acc</td><td>0.81475</td></tr><tr><td>loss</td><td>0.19473</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">morning-capybara-12</strong> at: <a href='https://wandb.ai/a-j-ch1386-self-emploid/basic-intro/runs/vkup63i9' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/basic-intro/runs/vkup63i9</a><br> View project at: <a href='https://wandb.ai/a-j-ch1386-self-emploid/basic-intro' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/basic-intro</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251112_162044-vkup63i9/logs</code>
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/home/aria/machine learning-my code/wandb/wandb/run-20251112_162050-i0k2kowv</code>
# Syncing run <strong><a href='https://wandb.ai/a-j-ch1386-self-emploid/basic-intro/runs/i0k2kowv' target="_blank">mild-tree-13</a></strong> to <a href='https://wandb.ai/a-j-ch1386-self-emploid/basic-intro' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/a-j-ch1386-self-emploid/basic-intro' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/basic-intro</a>
#  View run at <a href='https://wandb.ai/a-j-ch1386-self-emploid/basic-intro/runs/i0k2kowv' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/basic-intro/runs/i0k2kowv</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>acc</td><td>▁▆▅▇████</td></tr><tr><td>loss</td><td>█▆▃▁▁▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>acc</td><td>0.88055</td></tr><tr><td>loss</td><td>0.14175</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">mild-tree-13</strong> at: <a href='https://wandb.ai/a-j-ch1386-self-emploid/basic-intro/runs/i0k2kowv' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/basic-intro/runs/i0k2kowv</a><br> View project at: <a href='https://wandb.ai/a-j-ch1386-self-emploid/basic-intro' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/basic-intro</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251112_162050-i0k2kowv/logs</code>
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/home/aria/machine learning-my code/wandb/wandb/run-20251112_162054-jor13qme</code>
# Syncing run <strong><a href='https://wandb.ai/a-j-ch1386-self-emploid/basic-intro/runs/jor13qme' target="_blank">divine-sponge-14</a></strong> to <a href='https://wandb.ai/a-j-ch1386-self-emploid/basic-intro' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/a-j-ch1386-self-emploid/basic-intro' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/basic-intro</a>
#  View run at <a href='https://wandb.ai/a-j-ch1386-self-emploid/basic-intro/runs/jor13qme' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/basic-intro/runs/jor13qme</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>acc</td><td>▁▄▇▇█▇██</td></tr><tr><td>loss</td><td>█▄▃▃▁▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>acc</td><td>0.92202</td></tr><tr><td>loss</td><td>0.05649</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">divine-sponge-14</strong> at: <a href='https://wandb.ai/a-j-ch1386-self-emploid/basic-intro/runs/jor13qme' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/basic-intro/runs/jor13qme</a><br> View project at: <a href='https://wandb.ai/a-j-ch1386-self-emploid/basic-intro' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/basic-intro</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251112_162054-jor13qme/logs</code>
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/home/aria/machine learning-my code/wandb/wandb/run-20251112_162058-0q9do1hl</code>
# Syncing run <strong><a href='https://wandb.ai/a-j-ch1386-self-emploid/basic-intro/runs/0q9do1hl' target="_blank">cerulean-deluge-15</a></strong> to <a href='https://wandb.ai/a-j-ch1386-self-emploid/basic-intro' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/a-j-ch1386-self-emploid/basic-intro' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/basic-intro</a>
#  View run at <a href='https://wandb.ai/a-j-ch1386-self-emploid/basic-intro/runs/0q9do1hl' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/basic-intro/runs/0q9do1hl</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>acc</td><td>▁▆█▆▇█▇█</td></tr><tr><td>loss</td><td>█▆▂▁▁▁▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>acc</td><td>0.90143</td></tr><tr><td>loss</td><td>0.10638</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">cerulean-deluge-15</strong> at: <a href='https://wandb.ai/a-j-ch1386-self-emploid/basic-intro/runs/0q9do1hl' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/basic-intro/runs/0q9do1hl</a><br> View project at: <a href='https://wandb.ai/a-j-ch1386-self-emploid/basic-intro' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/basic-intro</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251112_162058-0q9do1hl/logs</code>

# %%
import random
import numpy as np
import tensorflow as tf
from wandb.keras import WandbMetricsLogger, WandbModelCheckpoint

# Simple Keras Model

# Launch 5 experiments, trying different dropout rates
for run in range(5):
    # Start a run, tracking hyperparameters
    wandb.init(
        project="keras-intro",
        config={
            "layer_1": 512,
            "activation_1": "relu",
            "dropout": random.uniform(0.01, 0.80),
            "layer_2": 10,
            "activation_2": "softmax",
            "optimizer": "sgd",
            "loss": "sparse_categorical_crossentropy",
            "metric": "accuracy",
            "epoch": 6,
            "batch_size": 256,
        },
    )
    config = wandb.config

    # Get the data
    mnist = tf.keras.datasets.mnist
    (x_train, y_train), (x_test, y_test) = mnist.load_data()
    x_train, x_test = x_train / 255.0, x_test / 255.0
    x_train, y_train = x_train[::5], y_train[::5]  # Subset data for a faster demo
    x_test, y_test = x_test[::20], y_test[::20]
    labels = [str(digit) for digit in range(np.max(y_train) + 1)]

    # Build a model
    model = tf.keras.models.Sequential(
        [
            tf.keras.layers.Flatten(input_shape=(28, 28)),
            tf.keras.layers.Dense(config.layer_1, activation=config.activation_1),
            tf.keras.layers.Dropout(config.dropout),
            tf.keras.layers.Dense(config.layer_2, activation=config.activation_2),
        ]
    )

    model.compile(optimizer=config.optimizer, loss=config.loss, metrics=[config.metric])

    # Add WandbMetricsLogger to log metrics and WandbModelCheckpoint to log model checkpoints
    wandb_callbacks = [
        WandbMetricsLogger(),
        WandbModelCheckpoint(filepath="my_model_{epoch:02d}"),
    ]

    model.fit(
        x=x_train,
        y=y_train,
        epochs=config.epoch,
        batch_size=config.batch_size,
        validation_data=(x_test, y_test),
        callbacks=wandb_callbacks,
    )

    # Mark the run as finished
    wandb.finish()
# Out:
# Finishing previous runs because reinit is set to 'default'.
#  View run <strong style="color:#cdcd00">sparkling-frost-2</strong> at: <a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro/runs/hsmdo0ig' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/keras-intro/runs/hsmdo0ig</a><br> View project at: <a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/keras-intro</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251112_163632-hsmdo0ig/logs</code>
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/home/aria/machine learning-my code/wandb/wandb/run-20251112_163759-7vezoite</code>
# Syncing run <strong><a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro/runs/7vezoite' target="_blank">wild-frog-3</a></strong> to <a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/keras-intro</a>
#  View run at <a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro/runs/7vezoite' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/keras-intro/runs/7vezoite</a>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 51
#      46 model.compile(optimizer=config.optimizer, loss=config.loss, metrics=[config.metric])
#      48 # Add WandbMetricsLogger to log metrics and WandbModelCheckpoint to log model checkpoints
#      49 wandb_callbacks = [
#      50     WandbMetricsLogger(),
# ---> 51     WandbModelCheckpoint(filepath="my_model_{epoch:02d}"),
#      52 ]
#      54 model.fit(
#      55     x=x_train,
#      56     y=y_train,
#    (...)
#      60     callbacks=wandb_callbacks,
#      61 )
#      63 # Mark the run as finished
#
# File /media/aria/SSD/anaconda/lib/python3.13/site-packages/wandb/integration/keras/callbacks/model_checkpoint.py:83, in WandbModelCheckpoint.__init__(self, filepath, monitor, verbose, save_best_only, save_weights_only, mode, save_freq, initial_value_threshold, **kwargs)
#      71 def __init__(
#      72     self,
#      73     filepath: StrPath,
#    (...)
#      81     **kwargs: Any,
#      82 ) -> None:
# ---> 83     super().__init__(
#      84         filepath=filepath,
#      85         monitor=monitor,
#      86         verbose=verbose,
#      87         save_best_only=save_best_only,
#      88         save_weights_only=save_weights_only,
#      89         mode=mode,
#      90         save_freq=save_freq,
#      91         initial_value_threshold=initial_value_threshold,
#      92         **kwargs,
#      93     )
#      94     if wandb.run is None:
#      95         raise wandb.Error(
#      96             "You must call `wandb.init()` before `WandbModelCheckpoint()`"
#      97         )
#
# File /media/aria/SSD/anaconda/lib/python3.13/site-packages/keras/src/callbacks/model_checkpoint.py:165, in ModelCheckpoint.__init__(self, filepath, monitor, verbose, save_best_only, save_weights_only, mode, save_freq, initial_value_threshold)
#     161 else:
#     162     if not any(
#     163         self.filepath.endswith(ext) for ext in (".keras", ".h5")
#     164     ):
# --> 165         raise ValueError(
#     166             "The filepath provided must end in `.keras` "
#     167             "(Keras model format). Received: "
#     168             f"filepath={self.filepath}"
#     169         )
#
# ValueError: The filepath provided must end in `.keras` (Keras model format). Received: filepath=my_model_{epoch:02d}

# %%
import numpy as np  # Fixed the typo in import statement
import random  # Added missing import for random
import tensorflow as tf
import wandb  # Added missing import for wandb
from wandb.keras import WandbMetricsLogger, WandbModelCheckpoint

# Simple Keras Model

# Launch 5 experiments, trying different dropout rates
for run in range(5):
    # Start a run, tracking hyperparameters
    wandb.init(
        project="keras-intro",
        config={
            "layer_1": 512,
            "activation_1": "relu",
            "dropout": random.uniform(0.01, 0.80),
            "layer_2": 10,
            "activation_2": "softmax",
            "optimizer": "sgd",
            "loss": "sparse_categorical_crossentropy",
            "metric": "accuracy",
            "epoch": 6,
            "batch_size": 256,
        },
    )
    config = wandb.config

    # Get the data
    mnist = tf.keras.datasets.mnist
    (x_train, y_train), (x_test, y_test) = mnist.load_data()
    x_train, x_test = x_train / 255.0, x_test / 255.0
    x_train, y_train = x_train[::5], y_train[::5]  # Subset data for a faster demo
    x_test, y_test = x_test[::20], y_test[::20]
    labels = [str(digit) for digit in range(np.max(y_train) + 1)]

    # Build a model
    model = tf.keras.models.Sequential(
        [
            tf.keras.layers.Flatten(input_shape=(28, 28)),
            tf.keras.layers.Dense(config.layer_1, activation=config.activation_1),
            tf.keras.layers.Dropout(config.dropout),
            tf.keras.layers.Dense(config.layer_2, activation=config.activation_2),
        ]
    )

    model.compile(optimizer=config.optimizer, loss=config.loss, metrics=[config.metric])

    # Add WandbMetricsLogger to log metrics and WandbModelCheckpoint to log model checkpoints
    # Fixed the filepath to include the .keras extension
    wandb_callbacks = [
        WandbMetricsLogger(),
        WandbModelCheckpoint(filepath="my_model_{epoch:02d}.keras"),
    ]

    model.fit(
        x=x_train,
        y=y_train,
        epochs=config.epoch,
        batch_size=config.batch_size,
        validation_data=(x_test, y_test),
        callbacks=wandb_callbacks,
    )

    # Mark the run as finished
    wandb.finish()
# Out:
# Finishing previous runs because reinit is set to 'default'.
#  View run <strong style="color:#cdcd00">wild-frog-3</strong> at: <a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro/runs/7vezoite' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/keras-intro/runs/7vezoite</a><br> View project at: <a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/keras-intro</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251112_163759-7vezoite/logs</code>
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/home/aria/machine learning-my code/wandb/wandb/run-20251112_163829-0igjqndz</code>
# Syncing run <strong><a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro/runs/0igjqndz' target="_blank">celestial-pond-4</a></strong> to <a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/keras-intro</a>
#  View run at <a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro/runs/0igjqndz' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/keras-intro/runs/0igjqndz</a>
# Epoch 1/6
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 75ms/step - accuracy: 0.1799 - loss: 2.2635 - val_accuracy: 0.5880 - val_loss: 1.8745
# Epoch 2/6
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.3783 - loss: 1.8694 - val_accuracy: 0.7160 - val_loss: 1.5589
# Epoch 3/6
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.5106 - loss: 1.6077 - val_accuracy: 0.7540 - val_loss: 1.3257
# Epoch 4/6
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.5828 - loss: 1.4112 - val_accuracy: 0.7800 - val_loss: 1.1487
# Epoch 5/6
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.6351 - loss: 1.2620 - val_accuracy: 0.7940 - val_loss: 1.0166
# Epoch 6/6
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.6649 - loss: 1.1558 - val_accuracy: 0.8120 - val_loss: 0.9151
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>▁▄▆▇██</td></tr><tr><td>epoch/epoch</td><td>▁▂▄▅▇█</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▆▄▃▂▁</td></tr><tr><td>epoch/val_accuracy</td><td>▁▅▆▇▇█</td></tr><tr><td>epoch/val_loss</td><td>█▆▄▃▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>0.66492</td></tr><tr><td>epoch/epoch</td><td>5</td></tr><tr><td>epoch/learning_rate</td><td>0.01</td></tr><tr><td>epoch/loss</td><td>1.15577</td></tr><tr><td>epoch/val_accuracy</td><td>0.812</td></tr><tr><td>epoch/val_loss</td><td>0.91507</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">celestial-pond-4</strong> at: <a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro/runs/0igjqndz' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/keras-intro/runs/0igjqndz</a><br> View project at: <a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/keras-intro</a><br>Synced 5 W&B file(s), 0 media file(s), 12 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251112_163829-0igjqndz/logs</code>
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/home/aria/machine learning-my code/wandb/wandb/run-20251112_163905-njvv6mz1</code>
# Syncing run <strong><a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro/runs/njvv6mz1' target="_blank">soft-lion-5</a></strong> to <a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/keras-intro</a>
#  View run at <a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro/runs/njvv6mz1' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/keras-intro/runs/njvv6mz1</a>
# Epoch 1/6
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.2039 - loss: 2.2127 - val_accuracy: 0.5940 - val_loss: 1.8217
# Epoch 2/6
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.4094 - loss: 1.8040 - val_accuracy: 0.7040 - val_loss: 1.5142
# Epoch 3/6
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.5414 - loss: 1.5353 - val_accuracy: 0.7580 - val_loss: 1.2864
# Epoch 4/6
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.6084 - loss: 1.3545 - val_accuracy: 0.7760 - val_loss: 1.1192
# Epoch 5/6
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.6531 - loss: 1.2133 - val_accuracy: 0.7980 - val_loss: 0.9943
# Epoch 6/6
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.6797 - loss: 1.1105 - val_accuracy: 0.7960 - val_loss: 0.8994
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>▁▄▆▇██</td></tr><tr><td>epoch/epoch</td><td>▁▂▄▅▇█</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▅▄▃▂▁</td></tr><tr><td>epoch/val_accuracy</td><td>▁▅▇▇██</td></tr><tr><td>epoch/val_loss</td><td>█▆▄▃▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>0.67967</td></tr><tr><td>epoch/epoch</td><td>5</td></tr><tr><td>epoch/learning_rate</td><td>0.01</td></tr><tr><td>epoch/loss</td><td>1.11049</td></tr><tr><td>epoch/val_accuracy</td><td>0.796</td></tr><tr><td>epoch/val_loss</td><td>0.89942</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">soft-lion-5</strong> at: <a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro/runs/njvv6mz1' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/keras-intro/runs/njvv6mz1</a><br> View project at: <a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/keras-intro</a><br>Synced 5 W&B file(s), 0 media file(s), 12 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251112_163905-njvv6mz1/logs</code>
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/home/aria/machine learning-my code/wandb/wandb/run-20251112_163939-mla7w9qo</code>
# Syncing run <strong><a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro/runs/mla7w9qo' target="_blank">fast-sky-6</a></strong> to <a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/keras-intro</a>
#  View run at <a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro/runs/mla7w9qo' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/keras-intro/runs/mla7w9qo</a>
# Epoch 1/6
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.1863 - loss: 2.2478 - val_accuracy: 0.5460 - val_loss: 1.8873
# Epoch 2/6
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.4078 - loss: 1.8498 - val_accuracy: 0.7060 - val_loss: 1.5590
# Epoch 3/6
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.5302 - loss: 1.5786 - val_accuracy: 0.7540 - val_loss: 1.3151
# Epoch 4/6
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.6149 - loss: 1.3664 - val_accuracy: 0.7800 - val_loss: 1.1333
# Epoch 5/6
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.6535 - loss: 1.2198 - val_accuracy: 0.8000 - val_loss: 0.9977
# Epoch 6/6
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.6910 - loss: 1.1054 - val_accuracy: 0.8120 - val_loss: 0.8948
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>▁▄▆▇▇█</td></tr><tr><td>epoch/epoch</td><td>▁▂▄▅▇█</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▆▄▃▂▁</td></tr><tr><td>epoch/val_accuracy</td><td>▁▅▆▇██</td></tr><tr><td>epoch/val_loss</td><td>█▆▄▃▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>0.691</td></tr><tr><td>epoch/epoch</td><td>5</td></tr><tr><td>epoch/learning_rate</td><td>0.01</td></tr><tr><td>epoch/loss</td><td>1.10544</td></tr><tr><td>epoch/val_accuracy</td><td>0.812</td></tr><tr><td>epoch/val_loss</td><td>0.89476</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fast-sky-6</strong> at: <a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro/runs/mla7w9qo' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/keras-intro/runs/mla7w9qo</a><br> View project at: <a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/keras-intro</a><br>Synced 5 W&B file(s), 0 media file(s), 12 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251112_163939-mla7w9qo/logs</code>
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/home/aria/machine learning-my code/wandb/wandb/run-20251112_164017-86ad9ogb</code>
# Syncing run <strong><a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro/runs/86ad9ogb' target="_blank">prime-lion-7</a></strong> to <a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/keras-intro</a>
#  View run at <a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro/runs/86ad9ogb' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/keras-intro/runs/86ad9ogb</a>
# Epoch 1/6
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.2093 - loss: 2.2034 - val_accuracy: 0.5780 - val_loss: 1.8716
# Epoch 2/6
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.4305 - loss: 1.8055 - val_accuracy: 0.7180 - val_loss: 1.5342
# Epoch 3/6
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.5642 - loss: 1.5259 - val_accuracy: 0.7700 - val_loss: 1.2867
# Epoch 4/6
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.6390 - loss: 1.3180 - val_accuracy: 0.7960 - val_loss: 1.1050
# Epoch 5/6
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.6831 - loss: 1.1675 - val_accuracy: 0.8020 - val_loss: 0.9731
# Epoch 6/6
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.7097 - loss: 1.0572 - val_accuracy: 0.8140 - val_loss: 0.8748
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>▁▄▆▇██</td></tr><tr><td>epoch/epoch</td><td>▁▂▄▅▇█</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▆▄▃▂▁</td></tr><tr><td>epoch/val_accuracy</td><td>▁▅▇▇██</td></tr><tr><td>epoch/val_loss</td><td>█▆▄▃▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>0.70975</td></tr><tr><td>epoch/epoch</td><td>5</td></tr><tr><td>epoch/learning_rate</td><td>0.01</td></tr><tr><td>epoch/loss</td><td>1.05716</td></tr><tr><td>epoch/val_accuracy</td><td>0.814</td></tr><tr><td>epoch/val_loss</td><td>0.87478</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">prime-lion-7</strong> at: <a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro/runs/86ad9ogb' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/keras-intro/runs/86ad9ogb</a><br> View project at: <a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/keras-intro</a><br>Synced 5 W&B file(s), 0 media file(s), 12 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251112_164017-86ad9ogb/logs</code>
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/home/aria/machine learning-my code/wandb/wandb/run-20251112_164058-2y5ahlfy</code>
# Syncing run <strong><a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro/runs/2y5ahlfy' target="_blank">eager-planet-8</a></strong> to <a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/keras-intro</a>
#  View run at <a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro/runs/2y5ahlfy' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/keras-intro/runs/2y5ahlfy</a>
# Epoch 1/6
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.1965 - loss: 2.2647 - val_accuracy: 0.5440 - val_loss: 1.9033
# Epoch 2/6
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.3830 - loss: 1.8667 - val_accuracy: 0.7080 - val_loss: 1.5843
# Epoch 3/6
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.5188 - loss: 1.5966 - val_accuracy: 0.7760 - val_loss: 1.3428
# Epoch 4/6
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.5913 - loss: 1.4036 - val_accuracy: 0.8000 - val_loss: 1.1624
# Epoch 5/6
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.6411 - loss: 1.2507 - val_accuracy: 0.8160 - val_loss: 1.0267
# Epoch 6/6
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.6788 - loss: 1.1351 - val_accuracy: 0.8280 - val_loss: 0.9223
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>▁▄▆▇▇█</td></tr><tr><td>epoch/epoch</td><td>▁▂▄▅▇█</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▆▄▃▂▁</td></tr><tr><td>epoch/val_accuracy</td><td>▁▅▇▇██</td></tr><tr><td>epoch/val_loss</td><td>█▆▄▃▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>0.67883</td></tr><tr><td>epoch/epoch</td><td>5</td></tr><tr><td>epoch/learning_rate</td><td>0.01</td></tr><tr><td>epoch/loss</td><td>1.13514</td></tr><tr><td>epoch/val_accuracy</td><td>0.828</td></tr><tr><td>epoch/val_loss</td><td>0.9223</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">eager-planet-8</strong> at: <a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro/runs/2y5ahlfy' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/keras-intro/runs/2y5ahlfy</a><br> View project at: <a href='https://wandb.ai/a-j-ch1386-self-emploid/keras-intro' target="_blank">https://wandb.ai/a-j-ch1386-self-emploid/keras-intro</a><br>Synced 5 W&B file(s), 0 media file(s), 12 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251112_164058-2y5ahlfy/logs</code>
