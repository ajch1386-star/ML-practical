# %%
from transformers import pipeline

# %%
clf = pipeline('fill-mask')
# Out:
# No model was supplied, defaulted to distilbert/distilroberta-base and revision fb53ab8 (https://huggingface.co/distilbert/distilroberta-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# '(ReadTimeoutError("HTTPSConnectionPool(host='huggingface.co', port=443): Read timed out. (read timeout=10)"), '(Request ID: 94939b90-4ba8-47aa-94e7-023e2ce77817)')' thrown while requesting HEAD https://huggingface.co/distilbert/distilroberta-base/resolve/fb53ab8/config.json
# Retrying in 1s [Retry 1/5].
# Some weights of the model checkpoint at distilbert/distilroberta-base were not used when initializing RobertaForMaskedLM: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %%
# Assuming clf is a masked language model function that requires a mask token
# Add the <mask> token to your input text
text_with_mask = "This is an example <mask> with the required mask token."
clf(text_with_mask)

# Alternatively, if you're using a specific library like transformers:
# from transformers import pipeline
# clf = pipeline("fill-mask")
# result = clf("This is an example <mask> with the required mask token.")
# Out:
# [{'score': 0.05260021239519119,
#   'token': 27314,
#   'token_str': ' screenshot',
#   'sequence': 'This is an example screenshot with the required mask token.'},
#  {'score': 0.028780128806829453,
#   'token': 11445,
#   'token_str': ' mask',
#   'sequence': 'This is an example mask with the required mask token.'},
#  {'score': 0.026920368894934654,
#   'token': 2274,
#   'token_str': ' image',
#   'sequence': 'This is an example image with the required mask token.'},
#  {'score': 0.025924542918801308,
#   'token': 2870,
#   'token_str': ' file',
#   'sequence': 'This is an example file with the required mask token.'},
#  {'score': 0.023368867114186287,
#   'token': 11808,
#   'token_str': ' setup',
#   'sequence': 'This is an example setup with the required mask token.'}]

# %%
#and question answering

# %%
clf1 = pipeline('question-answering')
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cpu

# %%
text= 'hi my name is aria and alex is stupid humen, alex is 35 years old '

# %%
clf1(question='who is alex',context=text)
# Out:
# {'score': 0.7637662887573242, 'start': 31, 'end': 43, 'answer': 'stupid humen'}
